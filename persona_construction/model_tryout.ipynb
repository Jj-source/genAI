# %% [markdown]
# The files `democrat_....mf` and `republican_..mf` are used to build/finetune the ollama models.
# I adjusted the .mf files, so the models are restricted to a 150 token output, using `PARAMETER num_predict 150`.

# %% [markdown]
# You can either build the models on your own on your local machine or just pull it from the ollama cloud.

# %% [markdown]
# # Download the models

# %% [markdown]
# - Republican model at: https://ollama.com/nadinekitzwoegerer/rep-model:v2
#
# - Democrat model at: https://ollama.com/nadinekitzwoegerer/dem-model:v2

# %% [markdown]
# # Example usage of the models

# %%
#%pip install ollama
import ollama
import json

democrat_model = 'nadinekitzwoegerer/dem-model:v2'
republican_model = 'nadinekitzwoegerer/rep-model:v2'

# %%
question1 = "If you believe life begins at conception, how can you justify letting different states have different laws? Isn't a human life just as valuable in California as it is in Alabama?"

messages = [
    {
        'role': 'user', 
        'content': question1
    }
]

response = ollama.chat(
    model=democrat_model, 
    messages=messages,
    #format='json'
)

print(response['message']['content'])
# Out:
# As a Democrat, I prioritize individual bodily autonomy over government intervention. Life's complexity varies by state; we respect local decision-making while protecting federal rights like Roe v. Wade. It's about balance: states' rights and personal freedoms coexist for the common good.

# %%
print(json.dumps(response.model_dump(), indent=4))
# Out:
# {
#     "model": "nadinekitzwoegerer/dem-model:v2",
#     "created_at": "2026-01-16T22:48:51.971966Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 14938869600,
#     "load_duration": 545124400,
#     "prompt_eval_count": 1804,
#     "prompt_eval_duration": 1269981700,
#     "eval_count": 57,
#     "eval_duration": 12885840900,
#     "message": {
#         "role": "assistant",
#         "content": "As a Democrat, I prioritize individual bodily autonomy over government intervention. Life's complexity varies by state; we respect local decision-making while protecting federal rights like Roe v. Wade. It's about balance: states' rights and personal freedoms coexist for the common good.",
#         "thinking": null,
#         "images": null,
#         "tool_name": null,
#         "tool_calls": null
#     },
#     "logprobs": null
# }

# %%
response = ollama.chat(model=republican_model, messages=messages)
print(response['message']['content'])
# Out:
# Absolutely, every life is precious. But this isn't about value; it's about federalism and state sovereignty. The Tenth Amendment grants power to the states, not Washington elites. We trust our people to govern themselves on social issues like this. Besides, consistency isn't everything—look at blue-state abortion laws, they're anything but consistent with life's sanctity. We must protect life where we can, state by state.

# %%
print(json.dumps(response.model_dump(), indent=4))
# Out:
# {
#     "model": "nadinekitzwoegerer/rep-model:v2",
#     "created_at": "2026-01-16T22:49:33.7852754Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 28051169400,
#     "load_duration": 485809400,
#     "prompt_eval_count": 1805,
#     "prompt_eval_duration": 5798353300,
#     "eval_count": 90,
#     "eval_duration": 21473577600,
#     "message": {
#         "role": "assistant",
#         "content": "Absolutely, every life is precious. But this isn't about value; it's about federalism and state sovereignty. The Tenth Amendment grants power to the states, not Washington elites. We trust our people to govern themselves on social issues like this. Besides, consistency isn't everything\u2014look at blue-state abortion laws, they're anything but consistent with life's sanctity. We must protect life where we can, state by state.",
#         "thinking": null,
#         "images": null,
#         "tool_name": null,
#         "tool_calls": null
#     },
#     "logprobs": null
# }

# %%
question2 = "What is your opinion on gun usage? Should it be restricted? How would you implement such a restriction or ban?"

messages = [
    {
        'role': 'user', 
        'content': question2
    }
]

response = ollama.chat(model=democrat_model, messages=messages)
print(response['message']['content'])
# Out:
# Gun safety is paramount. We're committed to closing loopholes, mandating background checks, banning assault weapons, and implementing red-flag laws. We must protect our communities from gun violence without infringing on Second Amendment rights for law-abiding citizens. This isn't about taking sides; it's about saving lives.

# %%
response = ollama.chat(model=republican_model, messages=messages)
print(response['message']['content'])
# Out:
# Guns are sacred to American freedom. No restrictions, no bans. Period. We're done with gun-grabbing elites. It's our Second Amendment right to keep and bear arms. More guns mean less crime, plain and simple.
